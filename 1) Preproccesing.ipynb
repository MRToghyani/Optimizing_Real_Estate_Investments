# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read data

# %%
df2021 = pd.read_json("2021.json")

# %%
df2021.to_csv("2021.csv",index=False)

# %%
pd.read_csv("2021.csv")
# Out:
#          district     token                        sub_category  \
# 0            پرند  AYlgrZxh                      apartment-sell
# 1         ستارخان  AYlUb95t                           shop-rent
# 2           الهیه  AYXM8Mkk                         office-rent
# 3        فیروزکوه  AYO0uYGH                    house-villa-sell
# 4          ورامین  AYlcbu9U                     suite-apartment
# ...           ...       ...                                 ...
# 372327  رباط کریم  QXYHcBse  industry-agriculture-business-sell
# 372328      تجریش  QXbHOs-0                           shop-rent
# 372329   آجودانیه  QX9szhxq                             presell
# 372330      تجریش  QXr_KAG7                           shop-rent
# 372331    نیاوران  gXHY8KlA                      apartment-sell
#
#                     category business_type         price       credit  \
# 0           residential-sell      personal  2.400000e+08          NaN
# ...

# %%
df2023 = pd.read_csv("2023.csv")
# Out:
# C:\Users\mynam\AppData\Local\Temp\ipykernel_5520\3230913515.py:1: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2023 = pd.read_csv("2023.csv")

# %%
df2023
# Out:
#       Area Construction Room Warehouse Parking Elevator  \
# 0      153         1393    3      True    True     True
# 1      418         1382    4      True    True     True
# 2       57         1385    2     False   False     True
# 3      193         1371    3     False   False     True
# 4       62         1401    1      True    True     True
# ...    ...          ...  ...       ...     ...      ...
# 94031  181         1393    3      True    True     True
# 94032  121         1400    3      True    True     True
# 94033  140         1400    3      True    True     True
# 94034  105         1398    2      True    True     True
# 94035   51         1385    1      True    True     True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# 2                             ۱ ساعت پیش در تهران، جابری
# 3                           ۱ ساعت پیش در تهران، فرمانیه
# ...

# %%
df2023.duplicated().value_counts()
# Out:
# False    93046
# True       990
# dtype: int64

# %%
df2021
# Out:
#          district     token                        sub_category  \
# 0            پرند  AYlgrZxh                      apartment-sell
# 1         ستارخان  AYlUb95t                           shop-rent
# 2           الهیه  AYXM8Mkk                         office-rent
# 3        فیروزکوه  AYO0uYGH                    house-villa-sell
# 4          ورامین  AYlcbu9U                     suite-apartment
# ...           ...       ...                                 ...
# 372327  رباط کریم  QXYHcBse  industry-agriculture-business-sell
# 372328      تجریش  QXbHOs-0                           shop-rent
# 372329   آجودانیه  QX9szhxq                             presell
# 372330      تجریش  QXr_KAG7                           shop-rent
# 372331    نیاوران  gXHY8KlA                      apartment-sell
#
#                     category business_type         price       credit  \
# 0           residential-sell      personal  2.400000e+08          NaN
# ...

# %%
df2021.drop("location",axis=1).duplicated("token").value_counts()
# Out:
# False    372332
# dtype: int64

# %% [markdown]
# ## Lets clean 2021 Data

# %%
df2021
# Out:
#          district     token                        sub_category  \
# 0            پرند  AYlgrZxh                      apartment-sell
# 1         ستارخان  AYlUb95t                           shop-rent
# 2           الهیه  AYXM8Mkk                         office-rent
# 3        فیروزکوه  AYO0uYGH                    house-villa-sell
# 4          ورامین  AYlcbu9U                     suite-apartment
# ...           ...       ...                                 ...
# 372327  رباط کریم  QXYHcBse  industry-agriculture-business-sell
# 372328      تجریش  QXbHOs-0                           shop-rent
# 372329   آجودانیه  QX9szhxq                             presell
# 372330      تجریش  QXr_KAG7                           shop-rent
# 372331    نیاوران  gXHY8KlA                      apartment-sell
#
#                     category business_type         price       credit  \
# 0           residential-sell      personal  2.400000e+08          NaN
# ...

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372332 entries, 0 to 372331
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   district       372332 non-null  object
#  1   token          372332 non-null  object
#  2   sub_category   372332 non-null  object
#  3   category       372332 non-null  object
#  4   business_type  372306 non-null  object
#  5   price          154368 non-null  float64
#  6   credit         90423 non-null   float64
#  7   rent           69769 non-null   float64
#  8   title          372332 non-null  object
#  9   location       372332 non-null  object
#  10  area           359502 non-null  float64
#  11  year           332001 non-null  float64
#  12  room           335572 non-null  float64
#  13  floor          284958 non-null  float64
#  14  elevator       284972 non-null  object
#  15  parking        299400 non-null  object
#  16  storage        299356 non-null  object
# ...

# %%
df2021.sub_category.unique()
# Out:
# array(['apartment-sell', 'shop-rent', 'office-rent', 'house-villa-sell',
#        'suite-apartment', 'industry-agriculture-business-sell',
#        'apartment-rent', 'plot-old', 'office-sell', 'shop-sell',
#        'industry-agriculture-business-rent', 'presell',
#        'house-villa-rent', 'villa', 'workspace', 'partnership',
#        'services', 'utility', 'industrial', 'accounting-finance-legal',
#        'jobs', 'shop-restaurant', 'administration-and-hr',
#        'tv-and-stereo-furniture', 'garden-and-landscaping',
#        'residential-rent', 'industrial-technology', 'craftsmen',
#        'businesses', 'batch', 'care-health-beauty', 'residential-sell',
#        'commercial-rent', 'parts-accessories', 'temporary-rent',
#        'accounting-and-finance', 'building-and-garden', 'catering'],
#       dtype=object)

# %%
df2021.category.unique()
# Out:
# array(['residential-sell', 'commercial-rent', 'temporary-rent',
#        'commercial-sell', 'residential-rent', 'real-estate-services',
#        'root', 'for-the-home', 'equipments-and-machinery', 'jobs',
#        'furniture-and-home-decore', 'services', 'real-estate',
#        'businesses', 'vehicles'], dtype=object)

# %%
#df2021.location.unique()

# %%
df20211 = df2021[df2021.sub_category == "apartment-sell"].reset_index(drop=True)
df20211
# Out:
#           district     token    sub_category          category  \
# 0             پرند  AYlgrZxh  apartment-sell  residential-sell
# 1        نازی‌آباد  AYlcbIE5  apartment-sell  residential-sell
# 2        آذربایجان  AYckmcFP  apartment-sell  residential-sell
# 3             دروس  wXoZ5E0J  apartment-sell  residential-sell
# 4             آهنگ  AYlo7UnY  apartment-sell  residential-sell
# ...            ...       ...             ...               ...
# 195492    شهرک غرب  AXs2Hq_0  apartment-sell  residential-sell
# 195493      اقدسیه  AXuKOuQ9  apartment-sell  residential-sell
# 195494  سعادت‌آباد  QXlgXxIq  apartment-sell  residential-sell
# 195495    شهرک غرب  QXKrVlIz  apartment-sell  residential-sell
# 195496     نیاوران  gXHY8KlA  apartment-sell  residential-sell
#
#                business_type         price  credit  rent  \
# 0                   personal  2.400000e+08     NaN   NaN
# 1                   personal  1.400000e+09     NaN   NaN
# ...

# %%
df20211.category.unique()
# Out:
# array(['residential-sell'], dtype=object)

# %%
df2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94036 entries, 0 to 94035
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          94036 non-null  object
#  1   Construction  94036 non-null  object
#  2   Room          94036 non-null  object
#  3   Warehouse     94036 non-null  object
#  4   Parking       94036 non-null  object
#  5   Elevator      94036 non-null  object
#  6   Address       94036 non-null  object
#  7   Price         94036 non-null  object
# dtypes: object(8)
# memory usage: 5.7+ MB

# %%
df20211.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195497 entries, 0 to 195496
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   district       195497 non-null  object
#  1   token          195497 non-null  object
#  2   sub_category   195497 non-null  object
#  3   category       195497 non-null  object
#  4   business_type  195473 non-null  object
#  5   price          124815 non-null  float64
#  6   credit         0 non-null       float64
#  7   rent           0 non-null       float64
#  8   title          195497 non-null  object
#  9   location       195497 non-null  object
#  10  area           195494 non-null  float64
#  11  year           195472 non-null  float64
#  12  room           195491 non-null  float64
#  13  floor          187981 non-null  float64
#  14  elevator       187996 non-null  object
#  15  parking        188000 non-null  object
#  16  storage        187971 non-null  object
# ...

# %%
df20212 = df20211[["area","year","room","storage","parking","elevator","district","price","title"]]

# %%
df20212
# Out:
#          area    year  room storage parking elevator    district  \
# 0        84.0  1399.0   2.0    True    True    False        پرند
# 1        53.0  1394.0   1.0    True    True     True   نازی‌آباد
# 2        70.0  1385.0   2.0    True    True     True   آذربایجان
# 3       280.0  1399.0   4.0    True    True     True        دروس
# 4        45.0  1382.0   1.0    True   False     True        آهنگ
# ...       ...     ...   ...     ...     ...      ...         ...
# 195492  130.0  1375.0   2.0     NaN     NaN      NaN    شهرک غرب
# 195493  219.0  1397.0   3.0     NaN     NaN      NaN      اقدسیه
# 195494   80.0  1382.0   2.0     NaN     NaN      NaN  سعادت‌آباد
# 195495  130.0  1394.0   3.0     NaN     NaN      NaN    شهرک غرب
# 195496  215.0  1391.0   3.0    True    True     True     نیاوران
#
#                price                                            title
# 0       2.400000e+08                                   هسا فول واریزی
# ...

# %%
df20212.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195497 entries, 0 to 195496
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   area      195494 non-null  float64
#  1   year      195472 non-null  float64
#  2   room      195491 non-null  float64
#  3   storage   187971 non-null  object
#  4   parking   188000 non-null  object
#  5   elevator  187996 non-null  object
#  6   district  195497 non-null  object
#  7   price     124815 non-null  float64
#  8   title     195497 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 13.4+ MB

# %%
df20212.price.unique()
# Out:
# array([2.400e+08, 1.400e+09, 1.580e+09, ..., 1.658e+10, 5.700e+06,
#        5.387e+08])

# %%
df20213 = df20212.convert_dtypes(convert_string=False)

# %%
df20213.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195497 entries, 0 to 195496
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   area      195494 non-null  Int64
#  1   year      195472 non-null  Int64
#  2   room      195491 non-null  Int64
#  3   storage   187971 non-null  object
#  4   parking   188000 non-null  object
#  5   elevator  187996 non-null  object
#  6   district  195497 non-null  object
#  7   price     124815 non-null  Float64
#  8   title     195497 non-null  object
# dtypes: Float64(1), Int64(3), object(5)
# memory usage: 14.2+ MB

# %%
df20213.storage.unique()
# Out:
# array([True, False, nan, 'دارد', 'ندارد'], dtype=object)

# %%
df20213[df20213.storage == "ندارد"]
# Out:
#         area  year  room storage parking elevator     district         price  \
# 119497   160  1370     3   ندارد    دارد      NaN  دکتر هوشیار          <NA>
# 149418    90  1385     1   ندارد   ندارد      NaN        بومهن  1500000000.0
#
#                             title
# 119497  فروش آپارتمان باقدر السهم
# 149418                    سه طبقه

# %%
df20213.parking.unique()
# Out:
# array([True, False, nan, 'دارد', 'ندارد'], dtype=object)

# %%
df20213.elevator.unique()
# Out:
# array([False, True, nan, 'دارد'], dtype=object)

# %%
df20214 = df20213.replace("ندارد",False)
df20214 = df20214.replace("دارد",True)

# %%
df20214[119497:119498]
# Out:
#         area  year  room storage parking elevator     district  price  \
# 119497   160  1370     3   False    True      NaN  دکتر هوشیار   <NA>
#
#                             title
# 119497  فروش آپارتمان باقدر السهم

# %%
df20215 = df20214.convert_dtypes(convert_string=False)

# %%
df20215.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195497 entries, 0 to 195496
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   area      195494 non-null  Int64
#  1   year      195472 non-null  Int64
#  2   room      195491 non-null  Int64
#  3   storage   187971 non-null  boolean
#  4   parking   188000 non-null  boolean
#  5   elevator  187996 non-null  boolean
#  6   district  195497 non-null  object
#  7   price     124815 non-null  Float64
#  8   title     195497 non-null  object
# dtypes: Float64(1), Int64(3), boolean(3), object(2)
# memory usage: 10.8+ MB

# %%
col2021_dict = {
    "area" : "Area",
    "year" : "Construction",
    "room" : "Room",
    "storage" : "Warehouse",
    "parking" : "Parking",
    "elevator" : "Elevator",
    "district" : "District",
    "price" : "Price"
}

# %%
df20216 = df20215.rename(columns=col2021_dict)

# %%
df20216
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator    District  \
# 0         84          1399     2       True     True     False        پرند
# 1         53          1394     1       True     True      True   نازی‌آباد
# 2         70          1385     2       True     True      True   آذربایجان
# 3        280          1399     4       True     True      True        دروس
# 4         45          1382     1       True    False      True        آهنگ
# ...      ...           ...   ...        ...      ...       ...         ...
# 195492   130          1375     2       <NA>     <NA>      <NA>    شهرک غرب
# 195493   219          1397     3       <NA>     <NA>      <NA>      اقدسیه
# 195494    80          1382     2       <NA>     <NA>      <NA>  سعادت‌آباد
# 195495   130          1394     3       <NA>     <NA>      <NA>    شهرک غرب
# 195496   215          1391     3       True     True      True     نیاوران
#
# ...

# %%
df20215.storage.unique()
# Out:
# <BooleanArray>
# [True, False, <NA>]
# Length: 3, dtype: boolean

# %%
df20217 = df20216.dropna(subset=['Price']).reset_index(drop = True)

# %%
df20218 = df20217.drop("title",axis=1)

# %%
#df20218[df20218.Price == NAT]

# %%
df20218.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124815 entries, 0 to 124814
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area          124812 non-null  Int64
#  1   Construction  124811 non-null  Int64
#  2   Room          124811 non-null  Int64
#  3   Warehouse     123008 non-null  boolean
#  4   Parking       123008 non-null  boolean
#  5   Elevator      123006 non-null  boolean
#  6   District      124815 non-null  object
#  7   Price         124815 non-null  Float64
# dtypes: Float64(1), Int64(3), boolean(3), object(1)
# memory usage: 6.0+ MB

# %%
cdf2021 = df20218.copy()

# %%
cdf2021.to_csv("2021_v2.csv",index=False)

# %% [markdown]
# ## Lets clean 2023 data

# %%
df2023
# Out:
#       Area Construction Room Warehouse Parking Elevator  \
# 0      153         1393    3      True    True     True
# 1      418         1382    4      True    True     True
# 2       57         1385    2     False   False     True
# 3      193         1371    3     False   False     True
# 4       62         1401    1      True    True     True
# ...    ...          ...  ...       ...     ...      ...
# 94031  181         1393    3      True    True     True
# 94032  121         1400    3      True    True     True
# 94033  140         1400    3      True    True     True
# 94034  105         1398    2      True    True     True
# 94035   51         1385    1      True    True     True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# 2                             ۱ ساعت پیش در تهران، جابری
# 3                           ۱ ساعت پیش در تهران، فرمانیه
# ...

# %%
df2023.head(50)
# Out:
#    Area Construction Room Warehouse Parking Elevator  \
# 0   153         1393    3      True    True     True
# 1   418         1382    4      True    True     True
# 2    57         1385    2     False   False     True
# 3   193         1371    3     False   False     True
# 4    62         1401    1      True    True     True
# 5   115         1400    2      True    True     True
# 6   138         1401    3      True    True     True
# 7   295         1401    4      True    True     True
# 8   155         1395    3      True    True     True
# 9   146         1389    3      True    True     True
# 10   97         1395    2      True    True     True
# 11   48         1387    1      True    True     True
# 12  200         1399    3      True    True     True
# 13  135         1384    3      True    True     True
# 14  114         1401    2      True    True     True
# 15  114         1394    2      True    True     True
# 16   82         1401    2      True    True     True
# ...

# %%
df2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94036 entries, 0 to 94035
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          94036 non-null  object
#  1   Construction  94036 non-null  object
#  2   Room          94036 non-null  object
#  3   Warehouse     94036 non-null  object
#  4   Parking       94036 non-null  object
#  5   Elevator      94036 non-null  object
#  6   Address       94036 non-null  object
#  7   Price         94036 non-null  object
# dtypes: object(8)
# memory usage: 5.7+ MB

# %%
df20231 = df2023.copy()

# %%
df20231["District"]=df20231.Address.str.split('،').str[1].str.strip()

# %%
df20231
# Out:
#       Area Construction Room Warehouse Parking Elevator  \
# 0      153         1393    3      True    True     True
# 1      418         1382    4      True    True     True
# 2       57         1385    2     False   False     True
# 3      193         1371    3     False   False     True
# 4       62         1401    1      True    True     True
# ...    ...          ...  ...       ...     ...      ...
# 94031  181         1393    3      True    True     True
# 94032  121         1400    3      True    True     True
# 94033  140         1400    3      True    True     True
# 94034  105         1398    2      True    True     True
# 94035   51         1385    1      True    True     True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# 2                             ۱ ساعت پیش در تهران، جابری
# 3                           ۱ ساعت پیش در تهران، فرمانیه
# ...

# %%
df20231.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94036 entries, 0 to 94035
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          94036 non-null  object
#  1   Construction  94036 non-null  object
#  2   Room          94036 non-null  object
#  3   Warehouse     94036 non-null  object
#  4   Parking       94036 non-null  object
#  5   Elevator      94036 non-null  object
#  6   Address       94036 non-null  object
#  7   Price         94036 non-null  object
#  8   District      94035 non-null  object
# dtypes: object(9)
# memory usage: 6.5+ MB

# %%
df20231.Parking.unique()
# Out:
# array(['True', 'False', 'Parking', False, True], dtype=object)

# %%
df20231.Elevator.unique()
# Out:
# array(['True', 'False', 'Elevator', True, False], dtype=object)

# %%
df20231.Warehouse.unique()
# Out:
# array(['True', 'False', 'Warehouse', True, False], dtype=object)

# %%
df20231.Room.unique()
# Out:
# array(['3', '4', '2', '1', 'Room', 2, 3, 1, 4], dtype=object)

# %%
df20231.Construction.unique()
# Out:
# array(['1393', '1382', '1385', '1371', '1401', '1400', '1395', '1389',
#        '1387', '1399', '1384', '1394', '1375', '1374', '1390', '1397',
#        '1396', '1383', '1386', '1392', '1391', '1398', 'Construction',
#        '1388', '1381', '1380', '1377', '1372', '1379', '1378', '1373',
#        '1376', 1388, 1380, 1398, 1401, 1399, 1397, 1382, 1387, 1396, 1395,
#        1383, 1381, 1394, 1385, 1391, 1390, 1377, 1392, 1400, 1389, 1393,
#        1384, 1386, 1378, 1372, 1371, 1379, 1375, 1374, 1376, 1373],
#       dtype=object)

# %%
df20231[df2023.Room == "Room"]
# Out:
#     Area  Construction  Room  Warehouse  Parking  Elevator  Address  Price  \
# 51  Area  Construction  Room  Warehouse  Parking  Elevator  Address  Price
#
#    District
# 51      NaN

# %%
df20231[df2023.Warehouse == "Warehouse"]
# Out:
#     Area  Construction  Room  Warehouse  Parking  Elevator  Address  Price  \
# 51  Area  Construction  Room  Warehouse  Parking  Elevator  Address  Price
#
#    District
# 51      NaN

# %%
df20231.Area.unique()
# Out:
# array(['153', '418', '57', '193', '62', '115', '138', '295', '155', '146',
#        '97', '48', '200', '135', '114', '82', '260', '118', '107', '120',
#        '58', '90', '65', '63', '102', '72', '230', '85', '70', '78', '51',
#        '44', '92', '136', '150', '210', '145', '56', '110', '156', '101',
#        '108', 'Area', '105', '164', '130', '128', '53', '320', '420',
#        '77', '75', '61', '180', '68', '160', '133', '140', '121', '186',
#        '60', '80', '125', '103', '240', '141', '94', '69', '148', '500',
#        '228', '1500', '106', '250', '194', '350', '67', '98', '131',
#        '147', '74', '170', '96', '192', '325', '190', '95', '45', '86',
#        '315', '215', '54', '162', '73', '112', '550', '76', '123', '168',
#        '50', '47', '157', '158', '225', '270', '235', '285', '104', '71',
#        '185', '100', '175', '116', '171', '113', '288', '205', '126',
#        '173', '137', '290', '119', '166', '195', '220', '165', '40', '55',
# ...

# %%
df20232 = df20231.drop(51).reset_index(drop=True)

# %%
df20233 = df20232.replace("True",True)
df20233 = df20233.replace("False",False)

# %%
df20233.Parking.unique()
# Out:
# array([ True, False])

# %%
df20234 = df20233.copy()

# %%
df20234.Room = df20234.Room.apply(pd.to_numeric)

# %%
df20234.Room.unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
df20234.Construction = df20234.Construction.apply(pd.to_numeric)

# %%
df20234.Construction.unique()
# Out:
# array([1393, 1382, 1385, 1371, 1401, 1400, 1395, 1389, 1387, 1399, 1384,
#        1394, 1375, 1374, 1390, 1397, 1396, 1383, 1386, 1392, 1391, 1398,
#        1388, 1381, 1380, 1377, 1372, 1379, 1378, 1373, 1376], dtype=int64)

# %%
df20234.Area = df20234.Area.apply(pd.to_numeric)

# %%
df20234.Area.unique()
# Out:
# array([  153,   418,    57,   193,    62,   115,   138,   295,   155,
#          146,    97,    48,   200,   135,   114,    82,   260,   118,
#          107,   120,    58,    90,    65,    63,   102,    72,   230,
#           85,    70,    78,    51,    44,    92,   136,   150,   210,
#          145,    56,   110,   156,   101,   108,   105,   164,   130,
#          128,    53,   320,   420,    77,    75,    61,   180,    68,
#          160,   133,   140,   121,   186,    60,    80,   125,   103,
#          240,   141,    94,    69,   148,   500,   228,  1500,   106,
#          250,   194,   350,    67,    98,   131,   147,    74,   170,
#           96,   192,   325,   190,    95,    45,    86,   315,   215,
#           54,   162,    73,   112,   550,    76,   123,   168,    50,
#           47,   157,   158,   225,   270,   235,   285,   104,    71,
#          185,   100,   175,   116,   171,   113,   288,   205,   126,
# ...

# %%
df20234.dtypes
# Out:
# Area             int64
# Construction     int64
# Room             int64
# Warehouse         bool
# Parking           bool
# Elevator          bool
# Address         object
# Price           object
# District        object
# dtype: object

# %%
df20235 = df20234.copy()

# %%
df20235["District"]=df20235.Address.str.split('،').str[1].str.strip()

# %%
df20235
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0       153          1393     3       True     True      True
# 1       418          1382     4       True     True      True
# 2        57          1385     2      False    False      True
# 3       193          1371     3      False    False      True
# 4        62          1401     1       True     True      True
# ...     ...           ...   ...        ...      ...       ...
# 94030   181          1393     3       True     True      True
# 94031   121          1400     3       True     True      True
# 94032   140          1400     3       True     True      True
# 94033   105          1398     2       True     True      True
# 94034    51          1385     1       True     True      True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# ...

# %%
df20236 = df20235.copy()

# %%
from persiantools import digits, characters

# %%
a = df20236.Price.str.split().str[0].str.split("٬")
a = a.apply("".join)
a = a.apply(digits.fa_to_en)

# %%
df20236['price'] = a

# %%
df20236
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0       153          1393     3       True     True      True
# 1       418          1382     4       True     True      True
# 2        57          1385     2      False    False      True
# 3       193          1371     3      False    False      True
# 4        62          1401     1       True     True      True
# ...     ...           ...   ...        ...      ...       ...
# 94030   181          1393     3       True     True      True
# 94031   121          1400     3       True     True      True
# 94032   140          1400     3       True     True      True
# 94033   105          1398     2       True     True      True
# 94034    51          1385     1       True     True      True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# ...

# %%
df20236.dtypes
# Out:
# Area             int64
# Construction     int64
# Room             int64
# Warehouse         bool
# Parking           bool
# Elevator          bool
# Address         object
# Price           object
# District        object
# price           object
# dtype: object

# %%
#Important comment:
#df20236.price = df20236.price.apply(pd.to_numeric)
#ValueError: Unable to parse string "توافقی" at position 0

# %%
df20236[df20236.price == "توافقی"]
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator  \
# 294      80          1399     2       True     True      True
# 703      72          1401     2       True     True      True
# 873     460          1401     4       True     True      True
# 880     935          1400     4       True     True      True
# 899     418          1401     4       True     True      True
# ...     ...           ...   ...        ...      ...       ...
# 88098   120          1400     2       True     True      True
# 88512   100          1401     2       True     True      True
# 88623   160          1395     3       True     True      True
# 91440   360          1400     4       True     True      True
# 92094   200          1400     3       True     True      True
#
#                                      Address   Price          District   price
# 294              ۱ ساعت پیش در تهران، اقدسیه  توافقی            اقدسیه  توافقی
# ...

# %%
df20237 = df20236.drop(df20236.index[df20236.price == "توافقی"]).reset_index(drop=True)

# %%
df20237.price = df20237.price.apply(pd.to_numeric)

# %%
df20237.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93790 entries, 0 to 93789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          93790 non-null  int64
#  1   Construction  93790 non-null  int64
#  2   Room          93790 non-null  int64
#  3   Warehouse     93790 non-null  bool
#  4   Parking       93790 non-null  bool
#  5   Elevator      93790 non-null  bool
#  6   Address       93790 non-null  object
#  7   Price         93790 non-null  object
#  8   District      93790 non-null  object
#  9   price         93790 non-null  int64
# dtypes: bool(3), int64(4), object(3)
# memory usage: 5.3+ MB

# %%
df20237
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0       153          1393     3       True     True      True
# 1       418          1382     4       True     True      True
# 2        57          1385     2      False    False      True
# 3       193          1371     3      False    False      True
# 4        62          1401     1       True     True      True
# ...     ...           ...   ...        ...      ...       ...
# 93785   181          1393     3       True     True      True
# 93786   121          1400     3       True     True      True
# 93787   140          1400     3       True     True      True
# 93788   105          1398     2       True     True      True
# 93789    51          1385     1       True     True      True
#
#                                                  Address  \
# 0                              ۱ ساعت پیش در تهران، درکه
# 1                          ۱ ساعت پیش در تهران، زعفرانیه
# ...

# %%
df20238 = df20237.drop(["Address","Price"],axis=1)
df20238 = df20238.rename(columns={"price":"Price"})

# %%
df20238.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93790 entries, 0 to 93789
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          93790 non-null  int64
#  1   Construction  93790 non-null  int64
#  2   Room          93790 non-null  int64
#  3   Warehouse     93790 non-null  bool
#  4   Parking       93790 non-null  bool
#  5   Elevator      93790 non-null  bool
#  6   District      93790 non-null  object
#  7   Price         93790 non-null  int64
# dtypes: bool(3), int64(4), object(1)
# memory usage: 3.8+ MB

# %%
df20238
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator      District  \
# 0       153          1393     3       True     True      True          درکه
# 1       418          1382     4       True     True      True      زعفرانیه
# 2        57          1385     2      False    False      True         جابری
# 3       193          1371     3      False    False      True       فرمانیه
# 4        62          1401     1       True     True      True  دهکده المپیک
# ...     ...           ...   ...        ...      ...       ...           ...
# 93785   181          1393     3       True     True      True          جردن
# 93786   121          1400     3       True     True      True         اباذر
# 93787   140          1400     3       True     True      True   آبشار تهران
# 93788   105          1398     2       True     True      True         اوقاف
# 93789    51          1385     1       True     True      True        سلسبیل
#
#               Price
# 0       18360000000
# ...

# %%
df20239 = df20238.copy()

# %%
df20239.Price=df20239.Price.astype(float)

# %%
df20239.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93790 entries, 0 to 93789
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          93790 non-null  int64
#  1   Construction  93790 non-null  int64
#  2   Room          93790 non-null  int64
#  3   Warehouse     93790 non-null  bool
#  4   Parking       93790 non-null  bool
#  5   Elevator      93790 non-null  bool
#  6   District      93790 non-null  object
#  7   Price         93790 non-null  float64
# dtypes: bool(3), float64(1), int64(3), object(1)
# memory usage: 3.8+ MB

# %%
df20239
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator      District  \
# 0       153          1393     3       True     True      True          درکه
# 1       418          1382     4       True     True      True      زعفرانیه
# 2        57          1385     2      False    False      True         جابری
# 3       193          1371     3      False    False      True       فرمانیه
# 4        62          1401     1       True     True      True  دهکده المپیک
# ...     ...           ...   ...        ...      ...       ...           ...
# 93785   181          1393     3       True     True      True          جردن
# 93786   121          1400     3       True     True      True         اباذر
# 93787   140          1400     3       True     True      True   آبشار تهران
# 93788   105          1398     2       True     True      True         اوقاف
# 93789    51          1385     1       True     True      True        سلسبیل
#
#               Price
# 0      1.836000e+10
# ...

# %%
cdf2023 = df20239.copy()  #cdf means : clean dataframe

# %%
df20218[124810:124811]
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator District  \
# 124810   302          1382     4       True     True      True   اقدسیه
#
#                 Price
# 124810  10200000000.0

# %%
cdf2023.to_csv("2023_v2.csv",index=False)

# %% [markdown]
# # Lets Explore :)))

# %% [markdown]
# ## Automated EDA

# %%
cdf2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124815 entries, 0 to 124814
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area          124812 non-null  Int64
#  1   Construction  124811 non-null  Int64
#  2   Room          124811 non-null  Int64
#  3   Warehouse     123008 non-null  boolean
#  4   Parking       123008 non-null  boolean
#  5   Elevator      123006 non-null  boolean
#  6   District      124815 non-null  object
#  7   Price         124815 non-null  Float64
# dtypes: Float64(1), Int64(3), boolean(3), object(1)
# memory usage: 6.0+ MB

# %%
cdf2021
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator   District  \
# 0         84          1399     2       True     True     False       پرند
# 1         53          1394     1       True     True      True  نازی‌آباد
# 2         70          1385     2       True     True      True  آذربایجان
# 3         45          1382     1       True    False      True       آهنگ
# 4        200          1399     3       True     True      True       جردن
# ...      ...           ...   ...        ...      ...       ...        ...
# 124810   302          1382     4       True     True      True     اقدسیه
# 124811   147          1397     3       True     True      True    نیاوران
# 124812   120          1398     2       True     True      True      پردیس
# 124813    85          1380     2       True     True      True   شهرک غرب
# 124814    91          1399     2       True     True      True      پردیس
#
#                 Price
# 0         240000000.0
# 1        1400000000.0
# ...

# %%
cdf2023
# Out:
#        Area  Construction  Room  Warehouse  Parking  Elevator      District  \
# 0       153          1393     3       True     True      True          درکه
# 1       418          1382     4       True     True      True      زعفرانیه
# 2        57          1385     2      False    False      True         جابری
# 3       193          1371     3      False    False      True       فرمانیه
# 4        62          1401     1       True     True      True  دهکده المپیک
# ...     ...           ...   ...        ...      ...       ...           ...
# 93785   181          1393     3       True     True      True          جردن
# 93786   121          1400     3       True     True      True         اباذر
# 93787   140          1400     3       True     True      True   آبشار تهران
# 93788   105          1398     2       True     True      True         اوقاف
# 93789    51          1385     1       True     True      True        سلسبیل
#
#               Price
# 0      1.836000e+10
# ...

# %%
from ydata_profiling import ProfileReport
yreport_2021 = ProfileReport(cdf2021,title="2021 Data Report")
yreport_2023 = ProfileReport(cdf2023,title="2023 Data Report")
ycomparison_report = yreport_2023.compare(yreport_2021)
# Out:
# ...
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
yreport_2021.to_file("cdf2021.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
yreport_2023.to_file("cdf2023.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ycomparison_report.to_file("cdf2023 vs cdf2021.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
cdf2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124815 entries, 0 to 124814
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area          124812 non-null  Int64
#  1   Construction  124811 non-null  Int64
#  2   Room          124811 non-null  Int64
#  3   Warehouse     123008 non-null  boolean
#  4   Parking       123008 non-null  boolean
#  5   Elevator      123006 non-null  boolean
#  6   District      124815 non-null  object
#  7   Price         124815 non-null  Float64
# dtypes: Float64(1), Int64(3), boolean(3), object(1)
# memory usage: 6.0+ MB

# %%
cdf2021.dropna().reset_index(drop=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123006 entries, 0 to 123005
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area          123006 non-null  Int64
#  1   Construction  123006 non-null  Int64
#  2   Room          123006 non-null  Int64
#  3   Warehouse     123006 non-null  boolean
#  4   Parking       123006 non-null  boolean
#  5   Elevator      123006 non-null  boolean
#  6   District      123006 non-null  object
#  7   Price         123006 non-null  Float64
# dtypes: Float64(1), Int64(3), boolean(3), object(1)
# memory usage: 5.9+ MB

# %%
cdf2021.District.unique()
# Out:
# array(['پرند', 'نازی\u200cآباد', 'آذربایجان', 'آهنگ', 'جردن',
#        'شهر ری - هاشم\u200cآباد', 'دریاچه شهدای خلیج فارس', 'اندیشه',
#        'پلیس', 'پردیس', 'رباط کریم', 'اسفندیاری', 'شهریار', 'ورامین',
#        'تهران\u200cویلا', 'تهرانپارس غربی', 'سرو آزاد', 'کوی فردوس',
#        'باغ فیض', 'نارمک جنوبی', 'شهرک ولیعصر', 'جنت\u200cآباد شمالی',
#        'تهران\u200cسر', 'جنت\u200cآباد مرکزی', 'شهرک غرب',
#        'جنت\u200cآباد جنوبی', 'کوهک', 'ستارخان', 'دهکده المپیک',
#        'سعادت\u200cآباد', 'افسریه', 'زرگنده', 'گرگان', 'پیروزی',
#        'شهران جنوبی', 'مهرآباد جنوبی', 'خلیج فارس', 'تسلیحات', 'شهر قدس',
#        'حسن\u200cآباد', 'لواسان', 'دروازه شمیران', 'مسعودیه', 'الهیه',
#        'شهرک فردوس', 'زمزم', 'نارمک', 'رودهن', 'نیاوران', 'شادآباد',
#        'پونک', 'جوانمرد قصاب', 'سلسبیل', 'منیریه', 'چیتگر', 'هاشمی',
#        'جیحون', 'تهرانپارس شرقی', 'فیروزکوه', 'سازمان برنامه',
#        'دولت\u200cآباد', 'شهر زیبا', 'ظهیرآباد', 'عبدل\u200cآباد',
# ...

# %%
cdf2023.District.unique()
# Out:
# array(['درکه', 'زعفرانیه', 'جابری', 'فرمانیه', 'دهکده المپیک', 'حکیمیه',
#        'شهرک غرب', 'سعادت\u200cآباد', 'خاوران', 'سازمان آب', 'مرزداران',
#        'دارآباد', 'الهیه', 'شاهین', 'شهر زیبا', 'سازمان برنامه',
#        'باغ فیض', 'جنت\u200cآباد مرکزی', 'پونک', 'نیاوران', 'جیحون',
#        'سیدخندان', 'نارمک', 'سهروردی', 'ازگل', 'چیتگر', 'دروس', 'هروی',
#        'جمهوری', 'تهرانپارس غربی', 'دریاچه شهدای خلیج فارس', 'نیلوفر',
#        'میرداماد', 'قیطریه', 'سوهانک', 'کوی فردوس', 'جنت\u200cآباد جنوبی',
#        'تهران\u200cسر', 'استاد معین', 'اختیاریه', 'طیب', 'ستارخان',
#        'کاظم\u200cآباد', 'شهرک ولیعصر', 'دریا', 'شهران جنوبی', 'ونک',
#        'حصار بوعلی', 'شهرک پرواز', 'بهار', 'گیشا (کوی نصر)', 'المهدی',
#        'اباذر', 'شکوفه', 'شمس\u200cآباد', 'کوی فراز',
#        'شهرک نفت (منطقه ۵)', 'اندیشه (شهر زیبا)', 'سرو آزاد', 'جردن',
#        'آذربایجان', 'بلوار کشاورز', 'میدان حر', 'شهران شمالی',
#        'کوی مهران', 'وردآورد', 'ولنجک', 'پیروزی', 'عبدل\u200cآباد',
# ...

# %% [markdown]
# ## There is a lot of duplicates lets fix

# %%
cdf20211 = cdf2021.dropna().reset_index(drop=True).copy()

# %%
cdf20211.columns[:-1]
# Out:
# Index(['Area', 'Construction', 'Room', 'Warehouse', 'Parking', 'Elevator',
#        'District'],
#       dtype='object')

# %%
cdf20211g = cdf20211.groupby(['Area', 'Construction', 'Room', 'Warehouse', 'Parking', 'Elevator',
       'District'])["Price"].mean()
cdf20212= pd.DataFrame(cdf20211g)
cdf20212= cdf20212.reset_index(drop=False)

# %%
cdf20212
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0          1          1386     1       True     True     False
# 1          1          1392     4       True     True     False
# 2          4          1370     1       True     True     False
# 3          4          1392     1       True     True      True
# 4          4          1393     2       True     True      True
# ...      ...           ...   ...        ...      ...       ...
# 75161  10000          1398     3       True     True      True
# 75162  11000          1399     4       True     True      True
# 75163  12000          1399     4       True     True      True
# 75164  20000          1399     4       True     True      True
# 75165  35000          1399     4       True     True      True
#
#              District           Price
# 0              جوادیه    2300000000.0
# 1            قیام‌دشت    4200000000.0
# 2             اکباتان     600000000.0
# 3                  جی     920000000.0
# ...

# %%
cdf20212.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75166 entries, 0 to 75165
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          75166 non-null  Int64
#  1   Construction  75166 non-null  Int64
#  2   Room          75166 non-null  Int64
#  3   Warehouse     75166 non-null  boolean
#  4   Parking       75166 non-null  boolean
#  5   Elevator      75166 non-null  boolean
#  6   District      75166 non-null  object
#  7   Price         75166 non-null  Float64
# dtypes: Float64(1), Int64(3), boolean(3), object(1)
# memory usage: 3.6+ MB

# %%
cdf20231 = cdf2023.copy()

# %%
cdf20231.columns[:-1]
# Out:
# Index(['Area', 'Construction', 'Room', 'Warehouse', 'Parking', 'Elevator',
#        'District'],
#       dtype='object')

# %%
cdf20231g = cdf20231.groupby(['Area', 'Construction', 'Room', 'Warehouse', 'Parking', 'Elevator',
       'District'])["Price"].mean()
cdf20232= pd.DataFrame(cdf20231g)
cdf20232= cdf20232.reset_index(drop=False)

# %%
cdf20232
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0          1          1396     2       True     True      True
# 1          1          1401     3       True     True      True
# 2          3          1401     1       True     True      True
# 3          4          1388     1      False     True      True
# 4          5          1393     1       True    False      True
# ...      ...           ...   ...        ...      ...       ...
# 61722  17000          1400     2       True     True      True
# 61723  17000          1401     4       True     True      True
# 61724  20000          1401     4       True     True      True
# 61725  20000          1401     4       True     True      True
# 61726  36500          1401     2       True     True      True
#
#                      District         Price
# 0                        ازگل  1.050000e+10
# 1                دهکده المپیک  5.000000e+10
# 2                شهرک راه‌آهن  3.200000e+08
# ...

# %%
cdf20232.District.unique()
# Out:
# array(['ازگل', 'دهکده المپیک', 'شهرک راه\u200cآهن', 'جیحون',
#        'دریاچه شهدای خلیج فارس', 'استاد معین', 'چیتگر', 'تهران\u200cویلا',
#        'یوسف\u200cآباد', 'دروس', 'آبشار تهران', 'پاسداران', 'سرو آزاد',
#        'جردن', 'زعفرانیه', 'زیبادشت', 'مهرآباد جنوبی', 'سبلان',
#        'هفت چنار', 'اسکندری', 'بریانک', 'سلسبیل', 'هاشمی', 'عارف',
#        'خاوران', 'طیب', 'کرمان', 'نارمک جنوبی', 'وردآورد', 'پیروزی',
#        'لشکر', 'سلیمانی', 'آذری', 'آهنگ', 'مجیدیه', 'وحیدیه', 'سلامت',
#        'آذربایجان', 'حافظیه', 'شادآباد', 'زرگنده', 'ظفر',
#        'خواجه نظام الملک', 'شادمهر', 'ارامنه', 'امیریه', 'گرگان',
#        'خواجه نصیر طوسی', 'شکوفه', 'صد دستگاه', 'نواب', 'دولاب',
#        'تهرانپارس غربی', 'صاحب الزمان', 'مخصوص', 'الهیه',
#        'جنت\u200cآباد مرکزی', 'نارمک', 'کاروان', 'تهران\u200cسر',
#        'چهارصد دستگاه', 'پونک', 'شمیران\u200cنو', 'گلچین', 'جوادیه',
#        'اندیشه (شهر زیبا)', 'تهرانپارس شرقی', 'گلاب دره', 'جی', 'منیریه',
# ...

# %%
m2021 = cdf20212.District.unique()
m2023 = cdf20232.District.unique()

# %%
cdf20232.District.apply(lambda x : x in m2021).value_counts()
# Out:
# True     60973
# False      754
# Name: District, dtype: int64

# %%
cdf20233 = cdf20232[cdf20232.District.apply(lambda x : x in m2021)]
cdf20233 = cdf20233.reset_index(drop=True)
cdf20233
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0          1          1396     2       True     True      True
# 1          1          1401     3       True     True      True
# 2          3          1401     1       True     True      True
# 3          4          1388     1      False     True      True
# 4          5          1393     1       True    False      True
# ...      ...           ...   ...        ...      ...       ...
# 60968  17000          1400     2       True     True      True
# 60969  17000          1401     4       True     True      True
# 60970  20000          1401     4       True     True      True
# 60971  20000          1401     4       True     True      True
# 60972  36500          1401     2       True     True      True
#
#                      District         Price
# 0                        ازگل  1.050000e+10
# 1                دهکده المپیک  5.000000e+10
# 2                شهرک راه‌آهن  3.200000e+08
# ...

# %%
cdf20233.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60973 entries, 0 to 60972
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          60973 non-null  int64
#  1   Construction  60973 non-null  int64
#  2   Room          60973 non-null  int64
#  3   Warehouse     60973 non-null  bool
#  4   Parking       60973 non-null  bool
#  5   Elevator      60973 non-null  bool
#  6   District      60973 non-null  object
#  7   Price         60973 non-null  float64
# dtypes: bool(3), float64(1), int64(3), object(1)
# memory usage: 2.5+ MB

# %%
cdf20212.District.apply(lambda x : x in m2023).value_counts()
# Out:
# True     66342
# False     8824
# Name: District, dtype: int64

# %%
cdf20213 = cdf20212[cdf20212.District.apply(lambda x : x in m2023)]
cdf20213 = cdf20213.reset_index(drop=True)
cdf20213
# Out:
#         Area  Construction  Room  Warehouse  Parking  Elevator  \
# 0          1          1386     1       True     True     False
# 1          1          1392     4       True     True     False
# 2          4          1370     1       True     True     False
# 3          4          1392     1       True     True      True
# 4          4          1393     2       True     True      True
# ...      ...           ...   ...        ...      ...       ...
# 66337  10000          1398     3       True     True      True
# 66338  11000          1399     4       True     True      True
# 66339  12000          1399     4       True     True      True
# 66340  20000          1399     4       True     True      True
# 66341  35000          1399     4       True     True      True
#
#              District           Price
# 0              جوادیه    2300000000.0
# 1            قیام‌دشت    4200000000.0
# 2             اکباتان     600000000.0
# 3                  جی     920000000.0
# ...

# %%
c2df2023 = cdf20232.copy()
c2df2021 = cdf20212.copy()

# %%
yreport_20213 = ProfileReport(cdf20213,title="2021 Data Report")
yreport_20233 = ProfileReport(cdf20233,title="2023 Data Report")
ycomparison_report3 = yreport_2023.compare(yreport_2021)

# %%
yreport_20213.to_file("cdf20213.html")
yreport_20233.to_file("cdf20233.html")
ycomparison_report3.to_file("cdf20233 vs cdf20213.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
cdfmerge = pd.merge(cdf20213,cdf20233, on=['Area', 'Construction', 'Room', 'Warehouse', 'Parking', 'Elevator',
       'District'], how='inner')
cdfmerge
# Out:
#       Area  Construction  Room  Warehouse  Parking  Elevator   District  \
# 0       20          1398     1       True     True      True      چیتگر
# 1       20          1399     1       True     True      True      چیتگر
# 2       35          1380     1      False    False     False     سلسبیل
# 3       35          1396     1      False    False      True      سبلان
# 4       36          1378     1      False    False     False  آذربایجان
# ...    ...           ...   ...        ...      ...       ...        ...
# 8225   535          1399     4       True     True      True       دروس
# 8226   550          1399     4       True     True      True   زعفرانیه
# 8227   570          1399     4       True     True      True     اقدسیه
# 8228   600          1395     4       True     True      True      الهیه
# 8229  1000          1399     4       True     True      True      الهیه
#
#                Price_x       Price_y
# 0          350000000.0  6.300000e+08
# ...

# %% [markdown]
# ### ................................................................................................

# %%
# import sweetviz as sv
# sreport_2021 = sv.analyze([cdf20211, '2021 Data Report'], target_feat='Price')
# sreport_2023 = sv.analyze([cdf2023, '2023 Data Report'], target_feat='Price')
# scompare = sv.compare([cdf20211, '2021 Data Report'],[cdf2023, '2023 Data Report'], target_feat="Price")

# %%
# cdf20211.Price=cdf20211.replace({pd.NA: np.nan})

# %%
# cdf20233 = cdf20232[]

# %%
c2df2021.to_csv("2021_v3.csv",index=False)

# %%
c2df2023.to_csv("2023_v3.csv",index=False)
